# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib notebook

# %%
weather_file = "Weather_CSV/Weather_DeDuped.csv"

# %%
# Out:
#      Location  Year  Yearly Average Temp
# 0    Oklahoma  1990                61.84
# 1    Oklahoma  1991                61.77
# 2    Oklahoma  1992                60.08
# 3    Oklahoma  1993                58.40
# 4    Oklahoma  1994                60.04
# ..        ...   ...                  ...
# 150     Texas  2016                70.16
# 151     Texas  2017                70.88
# 152     Texas  2018                69.07
# 153     Texas  2019                69.58
# 154     Texas  2020                72.79
#
# [155 rows x 3 columns]

# %%
x_axis = np.arange(1990, 2021, 1)
Ok = Weather_df.loc[Weather_df["Location"]=="Oklahoma"]["Yearly Average Temp"]
Fl = Weather_df.loc[Weather_df["Location"]=="Florida"]["Yearly Average Temp"]
Ky = Weather_df.loc[Weather_df["Location"]=="Kentucky"]["Yearly Average Temp"]
Mo = Weather_df.loc[Weather_df["Location"]=="Missouri"]["Yearly Average Temp"]
Tx = Weather_df.loc[Weather_df["Location"]=="Texas"]["Yearly Average Temp"]

# %%
Oklahoma, = plt.plot(x_axis, Ok, marker="+",color="blue", linewidth=1, label="Oklahoma")
Flordia, = plt.plot(x_axis, Fl, marker="s", color="Red", linewidth=1, label="Flordia")
Kentucky, = plt.plot(x_axis, Ky, marker="o",color="indigo", linewidth=1, label="Kentucky")
Missouri, = plt.plot(x_axis, Mo, marker="d", color="darkorange", linewidth=1, label="Missouri")
Texas, = plt.plot(x_axis, Tx, marker="<",color="darkgreen", linewidth=1, label="Texas")
# Out:
# <img src="data:image/png;base64,..." width="961">

# %%
plt.legend(handles=[Oklahoma, Flordia, Kentucky, Missouri, Texas], loc="best")
plt.xlabel("Years")
plt.ylabel("Average Temperature (F)")
plt.title("Average Yearly Temperature Changes")
# plt.savefig("Images/Yearly_Change.png")
plt.show()

# %%
df=pd.DataFrame(pd.read_csv("cleaned_data.csv"))

# %%
by_year_df=df.groupby("Year")
by_year_df.head()
by_year_df.count()
year_counts=by_year_df.count()["Disaster Subgroup"].tolist()
year_counts
Counts = plt.bar(x_axis, year_counts,color="darkgreen", width=.75)
