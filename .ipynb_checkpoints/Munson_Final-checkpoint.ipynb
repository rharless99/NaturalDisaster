# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
weather_file = "Weather_CSV/Weather.csv"
disaster_file = "disaster_count_by_year&state.csv"

# %%
Weather_df = pd.read_csv(weather_file)
Weather_df.head()
# Out:
#    Location     Month  Year  Average Temperature  Wind Speed  Cloud Cover  \
# 0  Oklahoma   January  1990                 45.4        28.8         38.4
# 1  Oklahoma  February  1990                 45.4        31.2         51.2
# 2  Oklahoma     March  1990                 52.2        28.4         67.9
# 3  Oklahoma     April  1990                 58.9        42.7         65.2
# 4  Oklahoma       May  1990                 68.1        28.1         57.3
#
#    Relative Humidity  Precipitation  Yearly Average Temp  \
# 0              53.92           2.48                61.84
# 1              64.61           6.99                  NaN
# 2              71.51           7.54                  NaN
# 3              63.98           7.47                  NaN
# 4              68.32          10.40                  NaN
#
#    Average Precipitation
# 0                   5.29
# 1                    NaN
# 2                    NaN
# 3                    NaN
# 4                    NaN

# %%
Weather_df = Weather_df.drop(columns=['Average Temperature', 'Cloud Cover', 'Relative Humidity','Wind Speed', 'Precipitation'])

# %%
Weather_df_reduced = Weather_df.dropna(how='any')

# %%
Weather_df_reduced = Weather_df_reduced.drop(columns=['Month'])

# %%
Weather_df_years = Weather_df_reduced.loc[Weather_df_reduced["Year"]<=2010]

# %%
Weather_df_years
# Out:
#       Location  Year  Yearly Average Temp  Average Precipitation
# 0     Oklahoma  1990                61.84                   5.29
# 12    Oklahoma  1991                61.77                   5.41
# 24    Oklahoma  1992                60.08                   4.99
# 36    Oklahoma  1993                58.40                  15.24
# 48    Oklahoma  1994                60.04                   4.37
# ...        ...   ...                  ...                    ...
# 1664     Texas  2006                70.55                   2.96
# 1676     Texas  2007                67.74                   4.22
# 1688     Texas  2008                69.58                   1.37
# 1700     Texas  2009                69.33                   2.84
# 1712     Texas  2010                67.83                   3.09
#
# [105 rows x 4 columns]

# %%
disasters_df = pd.read_csv(disaster_file)
disasters_df.head()
# Out:
#    Year  AK  AL  AR  AZ  CA  CO  CT  DE  FL  ...  SD  TN  TX  UT  VA  VT  WA  \
# 0  1990   1  60  37   9   4   1   0   0  11  ...   1   3  64   0   0   5  26
# 1  1991   1  12  21   0   1   0   6   0   0  ...   0  31  70   0   0   0  17
# 2  1992   0   0   5   0  11   0   3   2  15  ...   8   0  29   0  28   5   1
# 3  1993   0   0   0  17  33   0   0   0   0  ...  39   0   3   0   1   4   7
# 4  1994   3  27   0   5   3   3   0   2  28  ...  22  88  42   2  33   0   4
#
#    WI  WV  WY
# 0  18   0   0
# 1   5   0   0
# 2  10   0   0
# 3  47   0   0
# 4   0   0   0
#
# [5 rows x 51 columns]

# %%
x_axis = disasters_df['Year']

# %%
OK = disasters_df['OK']
FL = disasters_df['FL']
MO = disasters_df['MO']
KY = disasters_df["KY"]
TX = disasters_df['TX']
Ok = Weather_df_years.loc[Weather_df_years["Location"]=="Oklahoma"]["Yearly Average Temp"]
Fl = Weather_df_years.loc[Weather_df_years["Location"]=="Florida"]["Yearly Average Temp"]
Ky = Weather_df_years.loc[Weather_df_years["Location"]=="Kentucky"]["Yearly Average Temp"]
Mo = Weather_df_years.loc[Weather_df_years["Location"]=="Missouri"]["Yearly Average Temp"]
Tx = Weather_df_years.loc[Weather_df_years["Location"]=="Texas"]["Yearly Average Temp"]
OkRain = Weather_df_years.loc[Weather_df_years["Location"]=="Oklahoma"]["Average Precipitation"]
FlRain = Weather_df_years.loc[Weather_df_years["Location"]=="Florida"]["Average Precipitation"]
KyRain = Weather_df_years.loc[Weather_df_years["Location"]=="Kentucky"]["Average Precipitation"]
MoRain = Weather_df_years.loc[Weather_df_years["Location"]=="Missouri"]["Average Precipitation"]
TxRain = Weather_df_years.loc[Weather_df_years["Location"]=="Texas"]["Average Precipitation"]

# %%
#OKLAHOMA
plt.plot(x_axis, Ok, marker="+",color="blue", linewidth=1, label="OK Temperature")
plt.legend(handles=Oklahoma, loc="best")
plt.xlabel("Years")
plt.ylabel("Average Yearly Temperature (F)")
plt.title("Average Yearly Temperature Changes")
plt.savefig("Images/OK_YearlyTemp_Change.png")
plt.xticks(Rotation=45)
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %%
plt.bar(x_axis, OK, color="darkgreen", width=.75, label='Total Disasters')
plt.legend(loc="best")
plt.xlabel("Years")
plt.ylabel("Total Natural Disasters")
plt.title("Natural Disasters")
plt.savefig("Images/OK_Disasters.png")
plt.xticks(Rotation=45)
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %%
Oklahoma, = plt.plot(x_axis, OkRain, marker="+",color="red", linewidth=1, label="OK Precipitation")
plt.legend(loc="best")
plt.xlabel("Years")
plt.ylabel("Average Precipitation (Inches)")
plt.title("Average Yearly Precipitation Changes")
plt.savefig("Images/OK_YearlyPrecip_Change.png")
plt.xticks(Rotation=45)
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %%
#Florida
plt.plot(x_axis, Fl, marker="+",color="blue", linewidth=1, label="FL Temperature")
plt.legend(loc="best")
plt.xlabel("Years")
plt.ylabel("Average Temperature (F)")
plt.title("Average Yearly Temperature Changes")
plt.savefig("Images/FL_YearlyTemp_Change.png")
plt.xticks(Rotation=45)
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %%
plt.bar(x_axis, FL, color="darkgreen", width=.75, label='Total Disasters')
plt.legend(loc="best")
plt.xlabel("Years")
plt.ylabel("Total Natural Disasters")
plt.title("Natural Disasters")
plt.savefig("Images/FL_Disasters.png")
plt.xticks(Rotation=45)
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %%
Florida, = plt.plot(x_axis, FlRain, marker="+",color="red", linewidth=1, label="FL Precipitation")
plt.legend(loc="best")
plt.xlabel("Years")
plt.ylabel("Average Precipitation (Inches)")
plt.title("Average Yearly Precipitation Changes")
plt.savefig("Images/FL_YearlyPrecip_Change.png")
plt.xticks(Rotation=45)
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %%
#Texas
plt.plot(x_axis, Tx, marker="+",color="blue", linewidth=1, label="Tx Temperature")
plt.legend(loc="best")
plt.xlabel("Years")
plt.ylabel("Average Temperature (F)")
plt.title("Average Yearly Temperature Changes")
plt.savefig("Images/Tx_YearlyTemp_Change.png")
plt.xticks(Rotation=45)
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %%
plt.bar(x_axis, TX, color="darkgreen", width=.75, label='Total Disasters')
plt.legend(loc="best")
plt.xlabel("Years")
plt.ylabel("Total Natural Disasters")
plt.title("Natural Disasters")
plt.savefig("Images/Tx_Disasters.png")
plt.xticks(Rotation=45)
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %%
plt.plot(x_axis, TxRain, marker="+",color="red", linewidth=2, label="Tx Precipitation")
plt.legend(loc="best")
plt.xlabel("Years")
plt.ylabel("Average Precipitation (Inches)")
plt.title("Average Yearly Precipitation Changes")
plt.savefig("Images/Tx_YearlyPrecip_Change.png")
plt.xticks(Rotation=45)
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %%
#Kentucky
plt.plot(x_axis, Ky, marker="+",color="blue", linewidth=1, label="Ky Temperature")
plt.legend(loc="best")
plt.xlabel("Years")
plt.ylabel("Average Temperature (F)")
plt.title("Average Yearly Temperature Changes")
plt.savefig("Images/Ky_YearlyTemp_Change.png")
plt.xticks(Rotation=45)
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %%
plt.bar(x_axis, KY, color="darkgreen", width=.75, label='Total Disasters')
plt.legend(loc="best")
plt.xlabel("Years")
plt.ylabel("Total Natural Disasters")
plt.title("Natural Disasters")
plt.savefig("Images/Ky_Disasters.png")
plt.xticks(Rotation=45)
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %%
plt.plot(x_values, KyRain, marker="+",color="red", linewidth=2, label="Ky Precipitation")
plt.legend(loc="best")
plt.xlabel("Years")
plt.ylabel("Average Precipitation (Inches)")
plt.title("Average Yearly Precipitation Changes")
plt.savefig("Images/Ky_YearlyPrecip_Change.png")
plt.xticks(Rotation=45)
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %%
# Missouri
plt.plot(x_axis, Mo, marker="+",color="blue", linewidth=1, label="MO Temperature")
plt.legend(loc="best")
plt.xlabel("Years")
plt.ylabel("Average Temperature (F)")
plt.title("Average Yearly Temperature Changes")
plt.savefig("Images/Mo_YearlyTemp_Change.png")
plt.xticks(Rotation=45)
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %%
plt.bar(x_axis, MO, color="darkgreen", width=.75, label='Total Disasters')
plt.legend(loc="best")
plt.xlabel("Years")
plt.ylabel("Total Natural Disasters")
plt.title("Natural Disasters")
plt.savefig("Images/Mo_Disasters.png")
plt.xticks(Rotation=45)
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %%
plt.plot(x_values, MoRain, marker="+",color="red", linewidth=2, label="Ky Precipitation")
plt.legend(loc="best")
plt.xlabel("Years")
plt.ylabel("Average Precipitation (Inches)")
plt.title("Average Yearly Precipitation Changes")
plt.savefig("Images/Mo_YearlyPrecip_Change.png")
plt.xticks(Rotation=45)
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>
