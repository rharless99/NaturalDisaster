# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import gmaps
from config import g_key

# %%
df=pd.DataFrame(pd.read_csv("cleaned_data.csv"))

# %%
states_df=pd.DataFrame(pd.read_csv("world_country_and_usa_states_latitude_and_longitude_values.csv"))
states_df.head()
states=states_df["usa_state"].tolist()
states_df
# Out:
#    usa_state_code  usa_state_latitude  usa_state_longitude  \
# 0              AK           63.588753          -154.493062
# 1              AL           32.318231           -86.902298
# 2              AR           35.201050           -91.831833
# 3              AZ           34.048928          -111.093731
# 4              CA           36.778261          -119.417932
# 5              CO           39.550051          -105.782067
# 6              CT           41.603221           -73.087749
# 7              DC           38.905985           -77.033418
# 8              DE           38.910832           -75.527670
# 9              FL           27.664827           -81.515754
# 10             GA           32.157435           -82.907123
# 11             HI           19.898682          -155.665857
# 12             IA           41.878003           -93.097702
# 13             ID           44.068202          -114.742041
# 14             IL           40.633125           -89.398528
# 15             IN           40.551217           -85.602364
# 16             KS           39.011902           -98.484246
# 17             KY           37.839333           -84.270018
# 18             LA           31.244823           -92.145024
# 19             MA           42.407211           -71.382437
# 20             MD           39.045755           -76.641271
# 21             ME           45.253783           -69.445469
# 22             MI           44.314844           -85.602364
# 23             MN           46.729553           -94.685900
# 24             MO           37.964253           -91.831833
# 25             MS           32.354668           -89.398528
# 26             MT           46.879682          -110.362566
# 27             NC           35.759573           -79.019300
# 28             ND           47.551493          -101.002012
# 29             NE           41.492537           -99.901813
# 30             NH           43.193852           -71.572395
# 31             NJ           40.058324           -74.405661
# 32             NM           34.972730          -105.032363
# 33             NV           38.802610          -116.419389
# 34             NY           43.299428           -74.217933
# 35             OH           40.417287           -82.907123
# 36             OK           35.007752           -97.092877
# 37             OR           43.804133          -120.554201
# 38             PA           41.203322           -77.194525
# 39             PR           18.220833           -66.590149
# 40             RI           41.580095           -71.477429
# 41             SC           33.836081           -81.163725
# 42             SD           43.969515           -99.901813
# 43             TN           35.517491           -86.580447
# 44             TX           31.968599           -99.901813
# 45             UT           39.320980          -111.093731
# 46             VA           37.431573           -78.656894
# 47             VT           44.558803           -72.577841
# 48             WA           47.751074          -120.740139
# 49             WI           43.784440           -88.787868
# 50             WV           38.597626           -80.454903
# 51             WY           43.075968          -107.290284
#
#                usa_state
# 0                 Alaska
# 1                Alabama
# 2               Arkansas
# 3                Arizona
# 4             California
# 5               Colorado
# 6            Connecticut
# 7   District of Columbia
# 8               Delaware
# 9                Florida
# 10               Georgia
# 11                Hawaii
# 12                  Iowa
# 13                 Idaho
# 14              Illinois
# 15               Indiana
# 16                Kansas
# 17              Kentucky
# 18             Louisiana
# 19         Massachusetts
# 20              Maryland
# 21                 Maine
# 22              Michigan
# 23             Minnesota
# 24              Missouri
# 25           Mississippi
# 26               Montana
# 27        North Carolina
# 28          North Dakota
# 29              Nebraska
# 30         New Hampshire
# 31            New Jersey
# 32            New Mexico
# 33                Nevada
# 34              New York
# 35                  Ohio
# 36              Oklahoma
# 37                Oregon
# 38          Pennsylvania
# 39           Puerto Rico
# 40          Rhode Island
# 41        South Carolina
# 42          South Dakota
# 43             Tennessee
# 44                 Texas
# 45                  Utah
# 46              Virginia
# 47               Vermont
# 48            Washington
# 49             Wisconsin
# 50         West Virginia
# 51               Wyoming

# %%
df.head()
# Out:
#    Unnamed: 0         Dis No  Year Disaster Subgroup Disaster Type  \
# 0         175  1990-0346-USA  1990    Meteorological         Storm
# 1         176  1990-0357-USA  1990    Meteorological         Storm
# 2         177  1990-0359-USA  1990    Meteorological         Storm
# 3         178  1990-0360-USA  1990    Meteorological         Storm
# 4         179  1990-0363-USA  1990    Meteorological         Storm
#
#    Disaster Subtype Disaster Subsubtype  \
# 0  Convective storm        Severe storm
# 1  Convective storm        Severe storm
# 2  Convective storm        Severe storm
# 3  Convective storm        Severe storm
# 4  Convective storm        Severe storm
#
#                                             Location Origin Latitude  \
# 0  Oklahoma, Kansas, Nebraska, Missouri, Iowa, Il...    NaN      NaN
# 1  Texas, Oklahoma, Arkansas, Virginie, Caroline ...    NaN      NaN
# 2  Texas, Oklahoma, Arkansas, Kansas, Missouri, I...    NaN      NaN
# 3  Nebraska, Iowa, Kansas, Missouri, Texas, Oklah...    NaN      NaN
# 4      Colorado, Kansas, Missouri, Indiana, Kentucky    NaN      NaN
#
#   Longitude  Start Year  Start Month  Start Day  End Year  End Month  End Day  \
# 0       NaN        1990            3       13.0      1990        3.0     17.0
# 1       NaN        1990            5        1.0      1990        5.0      9.0
# 2       NaN        1990            5       14.0      1990        5.0     17.0
# 3       NaN        1990            5       18.0      1990        5.0     21.0
# 4       NaN        1990            6        6.0      1990        6.0      8.0
#
#    Total Deaths
# 0          15.0
# 1          13.0
# 2           NaN
# 3           NaN
# 4           NaN

# %%
cs_states=df["Location"].tolist()
test=cs_states[5] #Texas
state_counts=[]
for st in states:
    count=0
    for string in cs_states:
        if str(string).count(st)>0:
            count=count+1
    state_counts.append(count)

# %%
states_df["State Counts"]=state_counts
states_df
# Out:
#    usa_state_code  usa_state_latitude  usa_state_longitude  \
# 0              AK           63.588753          -154.493062
# 1              AL           32.318231           -86.902298
# 2              AR           35.201050           -91.831833
# 3              AZ           34.048928          -111.093731
# 4              CA           36.778261          -119.417932
# 5              CO           39.550051          -105.782067
# 6              CT           41.603221           -73.087749
# 7              DC           38.905985           -77.033418
# 8              DE           38.910832           -75.527670
# 9              FL           27.664827           -81.515754
# 10             GA           32.157435           -82.907123
# 11             HI           19.898682          -155.665857
# 12             IA           41.878003           -93.097702
# 13             ID           44.068202          -114.742041
# 14             IL           40.633125           -89.398528
# 15             IN           40.551217           -85.602364
# 16             KS           39.011902           -98.484246
# 17             KY           37.839333           -84.270018
# 18             LA           31.244823           -92.145024
# 19             MA           42.407211           -71.382437
# 20             MD           39.045755           -76.641271
# 21             ME           45.253783           -69.445469
# 22             MI           44.314844           -85.602364
# 23             MN           46.729553           -94.685900
# 24             MO           37.964253           -91.831833
# 25             MS           32.354668           -89.398528
# 26             MT           46.879682          -110.362566
# 27             NC           35.759573           -79.019300
# 28             ND           47.551493          -101.002012
# 29             NE           41.492537           -99.901813
# 30             NH           43.193852           -71.572395
# 31             NJ           40.058324           -74.405661
# 32             NM           34.972730          -105.032363
# 33             NV           38.802610          -116.419389
# 34             NY           43.299428           -74.217933
# 35             OH           40.417287           -82.907123
# 36             OK           35.007752           -97.092877
# 37             OR           43.804133          -120.554201
# 38             PA           41.203322           -77.194525
# 39             PR           18.220833           -66.590149
# 40             RI           41.580095           -71.477429
# 41             SC           33.836081           -81.163725
# 42             SD           43.969515           -99.901813
# 43             TN           35.517491           -86.580447
# 44             TX           31.968599           -99.901813
# 45             UT           39.320980          -111.093731
# 46             VA           37.431573           -78.656894
# 47             VT           44.558803           -72.577841
# 48             WA           47.751074          -120.740139
# 49             WI           43.784440           -88.787868
# 50             WV           38.597626           -80.454903
# 51             WY           43.075968          -107.290284
#
#                usa_state  State Counts
# 0                 Alaska             7
# 1                Alabama           106
# 2               Arkansas           103
# 3                Arizona            27
# 4             California           104
# 5               Colorado            70
# 6            Connecticut            47
# 7   District of Columbia            17
# 8               Delaware            34
# 9                Florida            82
# 10               Georgia            99
# 11                Hawaii             5
# 12                  Iowa            89
# 13                 Idaho            16
# 14              Illinois           134
# 15               Indiana           108
# 16                Kansas           124
# 17              Kentucky           102
# 18             Louisiana            99
# 19         Massachusetts            50
# 20              Maryland            65
# 21                 Maine            38
# 22              Michigan            67
# 23             Minnesota            74
# 24              Missouri           143
# 25           Mississippi            99
# 26               Montana            30
# 27        North Carolina            97
# 28          North Dakota            34
# 29              Nebraska            75
# 30         New Hampshire            34
# 31            New Jersey            74
# 32            New Mexico            34
# 33                Nevada            27
# 34              New York           104
# 35                  Ohio           112
# 36              Oklahoma           127
# 37                Oregon            29
# 38          Pennsylvania            94
# 39           Puerto Rico             0
# 40          Rhode Island            39
# 41        South Carolina            68
# 42          South Dakota            47
# 43             Tennessee            95
# 44                 Texas           202
# 45                  Utah            14
# 46              Virginia            98
# 47               Vermont            33
# 48            Washington            51
# 49             Wisconsin            78
# 50         West Virginia            46
# 51               Wyoming            27

# %%
gmaps.configure(api_key=g_key)
locs=states_df[["usa_state_latitude", "usa_state_longitude"]]
myfig=gmaps.figure()
heatmap = gmaps.heatmap_layer(locs, weights=state_counts, 
                                 dissipating=False,max_intensity=states_df["State Counts"].max()-40,
                                 point_radius=1.5)
myfig.add_layer(heatmap)
myfig
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %%
info_box_template = """
<dl>
<dt>Disaster Count</dt><dd>{State Counts}</dd>
<dt>State</dt><dd>{usa_state}</dd>
</dl>
"""
# Store the DataFrame Row
# NOTE: be sure to update with your DataFrame name
state_info = [info_box_template.format(**row) for index, row in states_df.iterrows()]

# %%
marker_layer = gmaps.marker_layer(locs, info_box_content=state_info)
myfig.add_layer(marker_layer)
myfig
# Out:
# Figure(layout=FigureLayout(height='420px'))
